# %% [markdown]
# # Loading the TEGR1 Dataset
#
# This module produces the TEGR1 dataset. This module is the same as main.ipynb with the following changes:
# * Drop unsuccessful donations
# * Remove columns 'success', 'status', and 'type' as these values do not vary.
# * Shorten hashes to 10 total characters to increase readability
#
#
# Dropping unsuccessful rows changes the number of rows in the dataset thus you will notice a difference in the stats at the bottom of this notebook from main.ipynb.

# %%
import pandas as pd
import numpy as np
import panel as pn
import hvplot.pandas
from icecream import ic
from bokeh.models.formatters import NumeralTickFormatter
from bokeh.models import HoverTool
ic.configureOutput(prefix='ic|',outputFunction=print)
pn.extension('tabulator')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# ## Read Input Data
#
# Vote Coefficients Inputs Dataset

# %%
# Read the Vote Coefficients Inputs Dataset
ic("Loading data...")
df_qf = pd.read_csv('./input/vote_coefficients_input.csv', parse_dates=['last_score_timestamp'])
ic(df_qf.shape)

# Drop Unsuccessful Rows
ic(len(df_qf[df_qf['success']==False]))
ic("Dropping unsuccessful data...")
df_qf = df_qf[df_qf['success']==True]
ic(df_qf.shape)

# Drop Unecessary Columns
drop_columns=['success', 'status', 'type']
ic(drop_columns)
ic("Dropping columns...")
df_qf = df_qf.drop(drop_columns, axis=1)
ic(df_qf.shape)

# Shorten Hash Values for Easier Reading
ic("Shortening hashes...")
df_qf[df_qf.select_dtypes('object').columns] = df_qf.select_dtypes('object').apply(lambda x: np.where(x.str.startswith('0x'), x.str.slice(stop=10), x))

df_qf.head(5)
# Out:
# ic|'Loading data...'
# ic|df_qf.shape: (257, 16)
# ic|len(df_qf[df_qf['success']==False]): 4
# ic|'Dropping unsuccessful data...'
# ic|df_qf.shape: (253, 16)
# ic|drop_columns: ['success', 'status', 'type']
# ic|'Dropping columns...'
# ic|df_qf.shape: (253, 13)
# ic|'Shortening hashes...'
#            id   projectId  applicationId     roundId       token       voter  \
# 0  0x24a5bbf1  0x64a30a4b             19  0x9E669c0A  0x00000000  0x9ba96198
# 1  0x3dce13bb  0xc401c980              6  0x9E669c0A  0x00000000  0x9390fa86
# 2  0x4cf20243  0x97589cd1              7  0x9E669c0A  0x00000000  0x5136cdfc
# 3  0x2b032f10  0xec026845             16  0x9E669c0A  0x00000000  0x524cb61b
# 4  0x0842753b  0xa9bdf738             29  0x9E669c0A  0x00000000  0x524cb61b
#
#   grantAddress        amount  amountUSD  coefficient  \
# 0   0xA26d6AEB  5.000000e+15   9.184332            1
# 1   0x9390fA86  2.200000e+15   4.094567            1
# 2   0x0035cC37  4.000000e+16  74.446665            1
# 3   0x45b79C6b  3.000000e+15   5.583500            1
# 4   0x5041A1C1  3.000000e+15   5.583500            1
#
#               last_score_timestamp  rawScore  threshold
# 0 2023-04-25 13:48:59.888771+00:00     28.57         15
# 1 2023-04-25 16:55:55.447871+00:00     27.21         15
# 2 2023-04-25 17:25:19.667155+00:00     28.57         15
# 3 2023-04-25 17:07:33.303578+00:00     23.56         15
# 4 2023-04-25 17:07:33.303578+00:00     23.56         15

# %% [markdown]
# Exploring data with Tabulator

# %%
pn.widgets.Tabulator.theme = 'simple'
pn.widgets.Tabulator(df_qf, layout='fit_data_table', page_size=5)
# Out:
# Tabulator(page_size=5, pagination='local', value=             i...)

# %% [markdown]
# ### Introducing TE Commons Data

# %%
def shorten_hashes(df):
    df[df.select_dtypes('object').columns] = df.select_dtypes('object').apply(lambda x: np.where(x.str.startswith('0x'), x.str.slice(stop=10), x))
    return df

# %%
# get table of valid tec holders
# extracted from https://dune.com/queries/2457553/4040451
df_tec = shorten_hashes(pd.read_csv('./input/tec_holders.csv'))

df_tec
# Out:
#         address        balance  tec_tokens_flag
# 0    0x38dfd788  150071.717791                1
# 1    0x5b757549  106053.271906                1
# 2    0x839395e2   73838.661487                1
# 3    0xdf290293   69337.513233                1
# 4    0x45602bfb   59165.981018                1
# ..          ...            ...              ...
# 404  0x423d60df      10.873917                1
# 405  0xc70c7f14      10.674364                1
# 406  0xae7f1137      10.309472                1
# 407  0x96bdad64      10.223873                1
# 408  0x5ce077c8      10.179837                1
#
# [409 rows x 3 columns]

# %% [markdown]
# Visualize the data on a log scale with pretty blue circles.

# %%
# Use the Bokeh Hover Tool to show formatted numbers in the hover tooltip for balances
hover = HoverTool(tooltips=[("address", "@address"), ("balance", "@balance{0.00}")])

# Plot a scatter plot of TEC balances on a logy scale.
df_tec.hvplot.scatter(
    y='balance', 
    yformatter=NumeralTickFormatter(format='0,0'), 
    alpha=0.8, 
    logy=True, 
    hover_cols=['address', 'balance'],
    title="TEC Token Holders Distribution Log Scale",
    tools=[hover],
    size=200,
    color="white",
    line_color="skyblue",
    xlabel="index",
)
# Out:
# :Scatter   [index]   (balance,address)

# %% [markdown]
# ### Introducing TE Academy Data

# %%
# get table of te academy token holders
# extracted from https://dune.com/queries/2457581
df_tea_dune = shorten_hashes(pd.read_csv('./input/tea_holders_dune.csv'))
df_tea_tea = shorten_hashes(pd.read_excel('./input/tea_holders_tea.xlsx'))

# Combine
df_tea = pd.concat([df_tea_dune, df_tea_tea]).drop_duplicates(subset=['wallet'])

# Make a contiguous index
df_tea = df_tea.reset_index(drop=True)

# Fill balance of TEA with -1 for now
df_tea = df_tea.fillna(-1)

# %%
len(set(df_tea_tea['wallet']).intersection(set(df_tea_dune['wallet'])))
# Out:
# 151

# %%
len(df_tea_dune), len(df_tea_tea)
# Out:
# (192, 214)

# %%
df_tea
# Out:
#          wallet  balance  tea_flag
# 0    0x68f6f2db      1.0         1
# 1    0x3e0cf03f      5.0         1
# 2    0x1d1874f9      1.0         1
# 3    0x4daa278b      3.0         1
# 4    0xc710f3da      3.0         1
# ..          ...      ...       ...
# 244  0xe1954808     -1.0         1
# 245  0x7f990adf     -1.0         1
# 246  0xd1595177     -1.0         1
# 247  0xcc449df4     -1.0         1
# 248  0x5ce15dbc     -1.0         1
#
# [249 rows x 3 columns]

# %% [markdown]
# Visualize TEA Credentials with scatter and bar plots.

# %%
df_tea.hvplot.scatter(y='balance', x='index', title="TEA Credentials Balances Scatter Plot", alpha=0.8)
# Out:
# :Scatter   [index]   (balance)

# %%
df_tea.groupby('balance').count().hvplot.bar(y='wallet', title="TEA Credentials Balances Bar Chart", ylabel="Wallet Count", alpha=0.8)
# Out:
# :Bars   [balance]   (wallet)

# %% [markdown]
# # Calculate Coefficients

# %%
# Drop unecessary columns
df_coef = df_qf.drop(columns=['roundId', 'threshold', 'token', 'last_score_timestamp'])
df_coef
# Out:
#              id   projectId  applicationId       voter grantAddress  \
# 0    0x24a5bbf1  0x64a30a4b             19  0x9ba96198   0xA26d6AEB
# 1    0x3dce13bb  0xc401c980              6  0x9390fa86   0x9390fA86
# 2    0x4cf20243  0x97589cd1              7  0x5136cdfc   0x0035cC37
# 3    0x2b032f10  0xec026845             16  0x524cb61b   0x45b79C6b
# 4    0x0842753b  0xa9bdf738             29  0x524cb61b   0x5041A1C1
# ..          ...         ...            ...         ...          ...
# 252  0x26e1e300  0x97589cd1              7  0x4405f427   0x0035cC37
# 253  0xa21ca1aa  0xec026845             16  0xcdfbbe10   0x45b79C6b
# 254  0x634b5156  0xf1f4942d             24  0xcdfbbe10   0x4f8c531d
# 255  0x4efa29aa  0xcf3165f4             10  0x410d86e3   0x7f3eb18E
# 256  0x7b5b313f  0x64a30a4b             19  0xb5d64294   0xA26d6AEB
#
#            amount  amountUSD  coefficient  rawScore
# 0    5.000000e+15   9.184332            1     28.57
# 1    2.200000e+15   4.094567            1     27.21
# 2    4.000000e+16  74.446665            1     28.57
# 3    3.000000e+15   5.583500            1     23.56
# 4    3.000000e+15   5.583500            1     23.56
# ..            ...        ...          ...       ...
# 252  1.000000e+15   1.847803            1     29.74
# 253  1.000000e+15   1.843793            1     21.07
# 254  1.000000e+15   1.843793            1     21.07
# 255  1.000000e+15   1.843793            1     18.04
# 256  3.000000e+15   5.531378            1     18.04
#
# [253 rows x 9 columns]

# %%
# Left join the three tables
df_merged = df_qf.merge(
    df_tec, left_on='voter', right_on='address',how='left').merge(
    df_tea, left_on='voter', right_on='wallet',how='left', suffixes=('_tec', '_tea')).drop(columns=['address','wallet'])
df_merged.sample(5)
# Out:
#              id   projectId  applicationId     roundId       token  \
# 153  0xb3495eb0  0xe6424ab2             22  0x9E669c0A  0x00000000
# 84   0x322cc3a0  0xf1f4942d             24  0x9E669c0A  0x00000000
# 30   0xa8308afc  0x10b3f00e             28  0x9E669c0A  0x6B175474
# 89   0xf292f6b4  0xe6424ab2             22  0x9E669c0A  0x00000000
# 114  0xfa44e4b3  0xe8249a10             14  0x9E669c0A  0x00000000
#
#           voter grantAddress        amount  amountUSD  coefficient  \
# 153  0xb9b37535   0x8110d1D0  5.500000e+15  10.513136            1
# 84   0x4b2f6d3a   0x4f8c531d  3.000000e+15   5.747475            1
# 30   0xcd0d4cdb   0x69e001B7  6.000000e+18   6.005987            1
# 89   0x33878e07   0x8110d1D0  2.200000e+15   4.295035            1
# 114  0x84ad6912   0x9b55D80A  2.000000e+15   3.806080            1
#
#                 last_score_timestamp  rawScore  threshold  balance_tec  \
# 153 2023-05-04 09:31:35.306785+00:00     16.89         15          NaN
# 84  2023-04-24 20:12:41.581966+00:00     34.61         15          NaN
# 30  2023-04-25 12:39:48.973839+00:00     37.04         15          NaN
# 89  2023-04-24 19:55:54.572737+00:00     43.05         15   120.854459
# 114 2023-04-28 10:00:46.608206+00:00     24.32         15          NaN
#
#      tec_tokens_flag  balance_tea  tea_flag
# 153              NaN          NaN       NaN
# 84               NaN          NaN       NaN
# 30               NaN          NaN       NaN
# 89               1.0          NaN       NaN
# 114              NaN          NaN       NaN

# %%
# Replace Nan values with 0
df_merged = df_merged.fillna(0)

# Multiply coefficient by 1.5 if tec_flag or tea_flag = 1
df_merged['coefficient'] = 1 + 0.5 * (df_merged['tec_tokens_flag'].astype(int) | df_merged['tea_flag'].astype(int))
df_merged
# Out:
#              id   projectId  applicationId     roundId       token  \
# 0    0x24a5bbf1  0x64a30a4b             19  0x9E669c0A  0x00000000
# 1    0x3dce13bb  0xc401c980              6  0x9E669c0A  0x00000000
# 2    0x4cf20243  0x97589cd1              7  0x9E669c0A  0x00000000
# 3    0x2b032f10  0xec026845             16  0x9E669c0A  0x00000000
# 4    0x0842753b  0xa9bdf738             29  0x9E669c0A  0x00000000
# ..          ...         ...            ...         ...         ...
# 248  0x26e1e300  0x97589cd1              7  0x9E669c0A  0x00000000
# 249  0xa21ca1aa  0xec026845             16  0x9E669c0A  0x00000000
# 250  0x634b5156  0xf1f4942d             24  0x9E669c0A  0x00000000
# 251  0x4efa29aa  0xcf3165f4             10  0x9E669c0A  0x00000000
# 252  0x7b5b313f  0x64a30a4b             19  0x9E669c0A  0x00000000
#
#           voter grantAddress        amount  amountUSD  coefficient  \
# 0    0x9ba96198   0xA26d6AEB  5.000000e+15   9.184332          1.5
# 1    0x9390fa86   0x9390fA86  2.200000e+15   4.094567          1.0
# 2    0x5136cdfc   0x0035cC37  4.000000e+16  74.446665          1.0
# 3    0x524cb61b   0x45b79C6b  3.000000e+15   5.583500          1.0
# 4    0x524cb61b   0x5041A1C1  3.000000e+15   5.583500          1.0
# ..          ...          ...           ...        ...          ...
# 248  0x4405f427   0x0035cC37  1.000000e+15   1.847803          1.0
# 249  0xcdfbbe10   0x45b79C6b  1.000000e+15   1.843793          1.0
# 250  0xcdfbbe10   0x4f8c531d  1.000000e+15   1.843793          1.0
# 251  0x410d86e3   0x7f3eb18E  1.000000e+15   1.843793          1.0
# 252  0xb5d64294   0xA26d6AEB  3.000000e+15   5.531378          1.0
#
#                 last_score_timestamp  rawScore  threshold  balance_tec  \
# 0   2023-04-25 13:48:59.888771+00:00     28.57         15          0.0
# 1   2023-04-25 16:55:55.447871+00:00     27.21         15          0.0
# 2   2023-04-25 17:25:19.667155+00:00     28.57         15          0.0
# 3   2023-04-25 17:07:33.303578+00:00     23.56         15          0.0
# 4   2023-04-25 17:07:33.303578+00:00     23.56         15          0.0
# ..                               ...       ...        ...          ...
# 248 2023-05-09 22:47:57.682680+00:00     29.74         15          0.0
# 249 2023-05-09 23:03:19.951021+00:00     21.07         15          0.0
# 250 2023-05-09 23:03:19.951021+00:00     21.07         15          0.0
# 251 2023-05-09 23:24:15.932770+00:00     18.04         15          0.0
# 252 2023-05-09 23:42:11.672306+00:00     18.04         15          0.0
#
#      tec_tokens_flag  balance_tea  tea_flag
# 0                0.0          3.0       1.0
# 1                0.0          0.0       0.0
# 2                0.0          0.0       0.0
# 3                0.0          0.0       0.0
# 4                0.0          0.0       0.0
# ..               ...          ...       ...
# 248              0.0          0.0       0.0
# 249              0.0          0.0       0.0
# 250              0.0          0.0       0.0
# 251              0.0          0.0       0.0
# 252              0.0          0.0       0.0
#
# [253 rows x 17 columns]

# %% [markdown]
# # Statistics

# %%
df_merged = df_merged.replace(0,np.nan)

# %%
# some simple statistics on the left join
df_merged[['id','tec_tokens_flag','tea_flag']].count()
# Out:
# id                 253
# tec_tokens_flag    108
# tea_flag            44
# dtype: int64

# %%
# count the number of unique voters
df_merged[['voter','tec_tokens_flag','tea_flag']].drop_duplicates().count()
# Out:
# voter              83
# tec_tokens_flag    19
# tea_flag            8
# dtype: int64

# %%
# count the number of voters that have both tec and tea tokens
df_merged[(df_merged['tec_tokens_flag']==True) & (df_merged['tea_flag']==True)][['voter','tec_tokens_flag','tea_flag']].drop_duplicates().count()
# Out:
# voter              4
# tec_tokens_flag    4
# tea_flag           4
# dtype: int64

# %% [markdown]
# # The TEGR1 Dataset.

# %%
df_merged.to_csv('output/TEGR1.csv', index=False)
