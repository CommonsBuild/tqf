# %%
import param as pm
import numpy as np
import pandas as pd
import panel as pn
import string
import random
pn.extension('tabulator')
pd.set_option('display.max_columns', 500)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='dd98b321-7012-46dd-b42f-4faecaf9eb31'>
#   <div id="e9e0c565-2f80-4867-9718-994d4ad361a1" data-root-id="dd98b321-7012-46dd-b42f-4faecaf9eb31" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"a0524e1f-ef1b-4827-80d3-0b99dbc82b66":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"dd98b321-7012-46dd-b42f-4faecaf9eb31"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"58b92a5a-f4a7-4859-b149-eae27209fe98","attributes":{"plot_id":"dd98b321-7012-46dd-b42f-4faecaf9eb31","comm_id":"1a1790f3d26f453f8c4f1681034a5c89","client_comm_id":"f1975828401c4ce8a66496b8388769e1"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"a0524e1f-ef1b-4827-80d3-0b99dbc82b66","roots":{"dd98b321-7012-46dd-b42f-4faecaf9eb31":"e9e0c565-2f80-4867-9718-994d4ad361a1"},"root_ids":["dd98b321-7012-46dd-b42f-4faecaf9eb31"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
class TECQFSME(pm.Parameterized):
    boost_factor = pm.Number(1, bounds=(0,4), step=0.1, doc="Multiplicative factor to apply to boosting coefficient.")
    dataset  = pm.DataFrame(columns={'amountUSD', 'projectId', 'voter'}, precedence=-1, doc="Dataset of donations. Must contain amountUSD, projectId, and voter columns.")
    matching_pool = pm.Integer(25_000, bounds=(0, 100_000), step=5_000, doc="Matching pool amount.")
    total_donations = pm.Number(0, constant=True, doc="Summation of amountUSD from donations dataset.")
    total_funding_pool = pm.Number(0, constant=True, doc="Summation of matching_pool and total_donations.")
    allocations  = pm.DataFrame(precedence=-1, doc="Percentages allocation table.")
    results  = pm.DataFrame(precedence=-1, doc="Matched and unmatched funding amounts. Allocation percentages times funding amounts.")
    
    def __init__(self, **params):
        super().__init__(**params)
        self.dataset = self.qf(self.dataset)
        self.update()
        
    @staticmethod
    def qf(df, column_name='amountUSD', new_column_name='quadratic_amount'):
        """
        Takes a specefied column as the donations column. Applies the QF algorithm to produce a new specefied column and intermediate calculation columns.
        """
        df = df.copy(deep=True)
        df[f'{column_name}_allocation'] = df[column_name] / df[column_name].sum()
        df[f'sqrt({column_name})'] = np.sqrt(df[column_name])
        df[f'sum(sqrt({column_name}))'] = df.groupby('projectId')[f'sqrt({column_name})'].transform('sum')
        df[f'sq(sum(sqrt({column_name})))'] = df[f'sum(sqrt({column_name}))'].transform(lambda x: x**2)
        df[f'{new_column_name}_allocation'] = df[f'sq(sum(sqrt({column_name})))'] / df[f'sq(sum(sqrt({column_name})))'].sum()
        df[new_column_name] = df[column_name].sum() * df[f'{new_column_name}_allocation']
        return df
    
    @staticmethod
    def signal_boost_v1(df, boost_factor, boost_column='amountUSD', new_column_name='amount_boosted'):
        """
        Given a dataset and a specefied column, applies the flag boost algorithm.
        Requires that the dataset contain 'tec_token_flag' and 'tea_flag'.
        """
        df['coefficient'] = 1 + boost_factor * (df['tec_tokens_flag'].astype(int) | df['tea_flag'].astype(int))
        df[new_column_name] = df[boost_column] * df['coefficient']
        return df

    
    @pm.depends('boost_factor', 'matching_pool', watch=True)
    def update(self):
        # Update total donations and funding pool
        with pm.edit_constant(self):
            self.total_donations = self.dataset['amountUSD'].sum()
            self.total_funding_pool = self.matching_pool + self.total_donations
        
        with pm.parameterized.batch_call_watchers(self):
            # Generate and apply the signal boosting coefficient
            self.dataset = self.signal_boost_v1(self.dataset, self.boost_factor, boost_column='amountUSD', new_column_name='amount_boosted')

            # Compute the Boosted Allocation
            self.dataset = self.qf(self.dataset, column_name='amount_boosted', new_column_name='quadratic_amount_boosted')

            # Remove the intermediate steps
            # self.dataset = self.dataset[self.dataset.columns[~self.dataset.columns.str.contains('sqrt')]]

            # Create an allocations table that contains allocation percentages grouped and summed by project. 
            allocation_columns = ['projectId'] + list(self.dataset.columns[self.dataset.columns.str.contains('allocation')])
            self.allocations = self.dataset[allocation_columns].groupby('projectId').sum()

            # Generate the unmatched results table by multiplying allocation percentages by total donations
            unmatched_results = self.total_donations * self.allocations
            
            # Generate the matched results table by multiplying allocation percentages by total donations plus matching pool
            matched_results = self.total_funding_pool * self.allocations
            
            # Merge matched and unmatched results
            self.results = unmatched_results.merge(matched_results, left_index=True, right_index=True, suffixes=('_unmatched', '_matched'))
            
            # Sort results by funding amount
            self.results = self.results.sort_values('quadratic_amount_allocation_matched', ascending=False)
            
            # Add some stats to results
            self.results.insert(0, 'Donor Count', df.groupby('projectId')['voter'].nunique())
            self.results.insert(1, 'Mean Donation', df.groupby('projectId')['amountUSD'].mean())
            self.results.insert(2, 'Median Donation', df.groupby('projectId')['amountUSD'].agg(pd.Series.median))
            self.results.insert(3, 'Mode Donation', df.groupby('projectId')['amountUSD'].agg(lambda x: pd.Series.mode(x).to_list()))

            # Save the boosting percentage stat
            self.results['SME Percentage Boost'] = 100 * ((self.results['quadratic_amount_boosted_allocation_matched'] - self.results['quadratic_amount_allocation_matched']) / self.results['quadratic_amount_allocation_matched'])

# %%
w = 2
df = pd.DataFrame([list(np.ones(w)) + [w], ['a']*2+['b'], ["0x"+"".join(random.choices(string.hexdigits, k=8)) for _ in range(w+1)]]).T
df.columns = ['amountUSD', 'projectId', 'voter']
df['amountUSD'] = df['amountUSD'].astype(float)
df['tec_tokens_flag'] = 0
df['tea_flag'] = 0
df
# Out:
#    amountUSD projectId       voter  tec_tokens_flag  tea_flag
# 0        1.0         a  0x534Fc3a9                0         0
# 1        1.0         a  0x85736e1c                0         0
# 2        2.0         b  0xa5a6B71B                0         0

# %%
t = TECQFSME(dataset=df, matching_pool=0, boost_factor=0)

pn.Row(t)
# Out:
# Row
#     [0] Column(margin=(5, 10), name='TECQFSME')
#         [0] StaticText(value='<b>TECQFSME</b>')
#         [1] FloatSlider(end=4, name='Boost factor')
#         [2] IntSlider(end=100000, name='Matching pool', step=5000)
#         [3] FloatInput(description='Summation of a..., disabled=True, name='Total donations', value=4.0)
#         [4] FloatInput(description='Summation of m..., disabled=True, name='Total funding pool', value=4.0)

# %%
t.dataset
# Out:
#    amountUSD projectId       voter  tec_tokens_flag  tea_flag  \
# 0        1.0         a  0x534Fc3a9                0         0
# 1        1.0         a  0x85736e1c                0         0
# 2        2.0         b  0xa5a6B71B                0         0
#
#    amountUSD_allocation  sqrt(amountUSD)  sum(sqrt(amountUSD))  \
# 0                  0.25         1.000000              2.000000
# 1                  0.25         1.000000              2.000000
# 2                  0.50         1.414214              1.414214
#
#    sq(sum(sqrt(amountUSD)))  quadratic_amount_allocation  quadratic_amount  \
# 0                       4.0                          0.4               1.6
# 1                       4.0                          0.4               1.6
# 2                       2.0                          0.2               0.8
#
#    coefficient  amount_boosted  amount_boosted_allocation  \
# 0            1             1.0                       0.25
# 1            1             1.0                       0.25
# 2            1             2.0                       0.50
#
#    sqrt(amount_boosted)  sum(sqrt(amount_boosted))  \
# 0              1.000000                   2.000000
# 1              1.000000                   2.000000
# 2              1.414214                   1.414214
#
#    sq(sum(sqrt(amount_boosted)))  quadratic_amount_boosted_allocation  \
# 0                            4.0                                  0.4
# 1                            4.0                                  0.4
# 2                            2.0                                  0.2
#
#    quadratic_amount_boosted
# 0                       1.6
# 1                       1.6
# 2                       0.8

# %%
t.results.T#[['quadratic_amount_allocation_unmatched']]
# Out:
# projectId                                          a      b
# Donor Count                                        2      1
# Mean Donation                                    1.0    2.0
# Median Donation                                  1.0    2.0
# Mode Donation                                  [1.0]  [2.0]
# amountUSD_allocation_unmatched                   2.0    2.0
# quadratic_amount_allocation_unmatched            3.2    0.8
# amount_boosted_allocation_unmatched              2.0    2.0
# quadratic_amount_boosted_allocation_unmatched    3.2    0.8
# amountUSD_allocation_matched                     2.0    2.0
# quadratic_amount_allocation_matched              3.2    0.8
# amount_boosted_allocation_matched                2.0    2.0
# quadratic_amount_boosted_allocation_matched      3.2    0.8
# SME Percentage Boost                             0.0    0.0

# %% [markdown]
# * Number of donors
# * Describe Donations (Mean, Median, Mode)
# * Expand Dataset across tegr1

# %%
df = pd.read_csv('output/TEGR1.csv')

# %%
df
# Out:
#              id   projectId  applicationId       voter grantAddress  \
# 0    0x24a5bbf1  0x64a30a4b             19  0x9ba96198   0xA26d6AEB
# 1    0x3dce13bb  0xc401c980              6  0x9390fa86   0x9390fA86
# 2    0x4cf20243  0x97589cd1              7  0x5136cdfc   0x0035cC37
# 3    0x2b032f10  0xec026845             16  0x524cb61b   0x45b79C6b
# 4    0x0842753b  0xa9bdf738             29  0x524cb61b   0x5041A1C1
# ..          ...         ...            ...         ...          ...
# 248  0x26e1e300  0x97589cd1              7  0x4405f427   0x0035cC37
# 249  0xa21ca1aa  0xec026845             16  0xcdfbbe10   0x45b79C6b
# 250  0x634b5156  0xf1f4942d             24  0xcdfbbe10   0x4f8c531d
# 251  0x4efa29aa  0xcf3165f4             10  0x410d86e3   0x7f3eb18E
# 252  0x7b5b313f  0x64a30a4b             19  0xb5d64294   0xA26d6AEB
#
#            amount  amountUSD  coefficient  rawScore  balance_tec  \
# 0    5.000000e+15   9.184332          1.5     28.57          0.0
# 1    2.200000e+15   4.094567          1.0     27.21          0.0
# 2    4.000000e+16  74.446665          1.0     28.57          0.0
# 3    3.000000e+15   5.583500          1.0     23.56          0.0
# 4    3.000000e+15   5.583500          1.0     23.56          0.0
# ..            ...        ...          ...       ...          ...
# 248  1.000000e+15   1.847803          1.0     29.74          0.0
# 249  1.000000e+15   1.843793          1.0     21.07          0.0
# 250  1.000000e+15   1.843793          1.0     21.07          0.0
# 251  1.000000e+15   1.843793          1.0     18.04          0.0
# 252  3.000000e+15   5.531378          1.0     18.04          0.0
#
#      tec_tokens_flag  balance_tea  tea_flag
# 0                0.0          3.0       1.0
# 1                0.0          0.0       0.0
# 2                0.0          0.0       0.0
# 3                0.0          0.0       0.0
# 4                0.0          0.0       0.0
# ..               ...          ...       ...
# 248              0.0          0.0       0.0
# 249              0.0          0.0       0.0
# 250              0.0          0.0       0.0
# 251              0.0          0.0       0.0
# 252              0.0          0.0       0.0
#
# [253 rows x 13 columns]

# %%
tec_qf_sme = TECQFSME(dataset=df.copy(deep=True))

# %%
tec_qf_sme.results.T
# Out:
# projectId                                                                             0xe6424ab2  \
# Donor Count                                                                                   29
# Mean Donation                                                                          21.099676
# Median Donation                                                                         6.005987
# Mode Donation                                  [0.99877445, 1.00118087, 1.11549067, 1.2010037...
# amountUSD_allocation_unmatched                                                        611.890594
# quadratic_amount_allocation_unmatched                                                1379.771324
# amount_boosted_allocation_unmatched                                                   730.818873
# quadratic_amount_boosted_allocation_unmatched                                        1524.927106
# amountUSD_allocation_matched                                                         3132.149048
# quadratic_amount_allocation_matched                                                  7062.781288
# amount_boosted_allocation_matched                                                    3740.919796
# quadratic_amount_boosted_allocation_matched                                          7805.805529
# SME Percentage Boost                                                                   10.520278
#
# projectId                                        0x4cd41869  \
# Donor Count                                              25
# Mean Donation                                     20.367331
# Median Donation                                    9.859106
# Mode Donation                                  [1.90690299]
# amountUSD_allocation_unmatched                   509.183286
# quadratic_amount_allocation_unmatched           1078.514627
# amount_boosted_allocation_unmatched              343.687871
# quadratic_amount_boosted_allocation_unmatched    776.229628
# amountUSD_allocation_matched                    2606.410294
# quadratic_amount_allocation_matched             5520.706798
# amount_boosted_allocation_matched               1759.271425
# quadratic_amount_boosted_allocation_matched     3973.368627
# SME Percentage Boost                               -28.0279
#
# projectId                                                                             0xdd9b885d  \
# Donor Count                                                                                   14
# Mean Donation                                                                         134.753852
# Median Donation                                                                        18.707399
# Mode Donation                                  [1.00118087, 2.86921472, 3.72995, 5.68897744, ...
# amountUSD_allocation_unmatched                                                       2021.307778
# quadratic_amount_allocation_unmatched                                                1013.750531
# amount_boosted_allocation_unmatched                                                  1635.875869
# quadratic_amount_boosted_allocation_unmatched                                         887.319529
# amountUSD_allocation_matched                                                        10346.681735
# quadratic_amount_allocation_matched                                                  5189.191974
# amount_boosted_allocation_matched                                                    8373.730686
# quadratic_amount_boosted_allocation_matched                                          4542.016245
# SME Percentage Boost                                                                  -12.471609
#
# projectId                                                                             0x8d6f0c7b  \
# Donor Count                                                                                   24
# Mean Donation                                                                           9.597053
# Median Donation                                                                         5.873165
# Mode Donation                                  [0.36889034, 1.00118087, 1.11549067, 1.5126950...
# amountUSD_allocation_unmatched                                                        230.329281
# quadratic_amount_allocation_unmatched                                                 505.888334
# amount_boosted_allocation_unmatched                                                   263.823284
# quadratic_amount_boosted_allocation_unmatched                                         579.128987
# amountUSD_allocation_matched                                                          1179.01083
# quadratic_amount_allocation_matched                                                  2589.544079
# amount_boosted_allocation_matched                                                    1350.460124
# quadratic_amount_boosted_allocation_matched                                          2964.448746
# SME Percentage Boost                                                                   14.477632
#
# projectId                                        0xa9bdf738    0xe8249a10  \
# Donor Count                                              24            20
# Mean Donation                                      7.692555     12.548762
# Median Donation                                    4.740046      5.998856
# Mode Donation                                  [3.80607954]  [3.80607954]
# amountUSD_allocation_unmatched                   192.313869    263.524009
# quadratic_amount_allocation_unmatched             476.29644    413.356603
# amount_boosted_allocation_unmatched               213.11158    269.370444
# quadratic_amount_boosted_allocation_unmatched     510.39955    467.209868
# amountUSD_allocation_matched                     984.417323   1348.928192
# quadratic_amount_allocation_matched             2438.068922   2115.892128
# amount_boosted_allocation_matched               1090.876764   1378.854956
# quadratic_amount_boosted_allocation_matched     2612.636113   2391.556523
# SME Percentage Boost                                7.16006     13.028282
#
# projectId                                                                             0x64a30a4b  \
# Donor Count                                                                                   17
# Mean Donation                                                                          21.226625
# Median Donation                                                                         7.445838
# Mode Donation                                  [0.36889034, 1.00118087, 2.0037435, 5.53137786...
# amountUSD_allocation_unmatched                                                        360.852626
# quadratic_amount_allocation_unmatched                                                 305.351505
# amount_boosted_allocation_unmatched                                                   448.174721
# quadratic_amount_boosted_allocation_unmatched                                         360.184006
# amountUSD_allocation_matched                                                         1847.134471
# quadratic_amount_allocation_matched                                                   1563.03502
# amount_boosted_allocation_matched                                                    2294.119307
# quadratic_amount_boosted_allocation_matched                                          1843.711934
# SME Percentage Boost                                                                   17.957174
#
# projectId                                                                             0x97589cd1  \
# Donor Count                                                                                   19
# Mean Donation                                                                          14.448157
# Median Donation                                                                         4.740046
# Mode Donation                                  [1.00021748, 1.00118087, 1.20100375, 1.8478033...
# amountUSD_allocation_unmatched                                                        274.514986
# quadratic_amount_allocation_unmatched                                                 299.021282
# amount_boosted_allocation_unmatched                                                   285.035299
# quadratic_amount_boosted_allocation_unmatched                                         312.663326
# amountUSD_allocation_matched                                                         1405.188871
# quadratic_amount_allocation_matched                                                  1530.631836
# amount_boosted_allocation_matched                                                    1459.040306
# quadratic_amount_boosted_allocation_matched                                          1600.462807
# SME Percentage Boost                                                                    4.562232
#
# projectId                                                                             0x23387567  \
# Donor Count                                                                                   10
# Mean Donation                                                                          91.271693
# Median Donation                                                                         6.005987
# Mode Donation                                  [1.00118087, 1.49944528, 3.25177668, 3.72995, ...
# amountUSD_allocation_unmatched                                                        1003.98862
# quadratic_amount_allocation_unmatched                                                 227.002239
# amount_boosted_allocation_unmatched                                                  1302.095947
# quadratic_amount_boosted_allocation_unmatched                                         288.275857
# amountUSD_allocation_matched                                                          5139.22265
# quadratic_amount_allocation_matched                                                  1161.980352
# amount_boosted_allocation_matched                                                     6665.17613
# quadratic_amount_boosted_allocation_matched                                          1475.628092
# SME Percentage Boost                                                                   26.992517
#
# projectId                                                                             0xec026845  \
# Donor Count                                                                                   17
# Mean Donation                                                                           9.953153
# Median Donation                                                                         5.688977
# Mode Donation                                  [1.00118087, 1.84379262, 1.8478033, 2.0037435,...
# amountUSD_allocation_unmatched                                                          169.2036
# quadratic_amount_allocation_unmatched                                                 192.269814
# amount_boosted_allocation_unmatched                                                   177.613917
# quadratic_amount_boosted_allocation_unmatched                                         197.708737
# amountUSD_allocation_matched                                                          866.120349
# quadratic_amount_allocation_matched                                                   984.191815
# amount_boosted_allocation_matched                                                     909.171127
# quadratic_amount_boosted_allocation_matched                                          1012.032606
# SME Percentage Boost                                                                    2.828797
#
# projectId                                        0xf1f4942d  \
# Donor Count                                              12
# Mean Donation                                      16.77284
# Median Donation                                    5.747475
# Mode Donation                                  [3.80607954]
# amountUSD_allocation_unmatched                   218.046923
# quadratic_amount_allocation_unmatched            116.445568
# amount_boosted_allocation_unmatched              171.373092
# quadratic_amount_boosted_allocation_unmatched     98.018407
# amountUSD_allocation_matched                    1116.139829
# quadratic_amount_allocation_matched              596.062233
# amount_boosted_allocation_matched                877.225555
# quadratic_amount_boosted_allocation_matched      501.737178
# SME Percentage Boost                             -15.824699
#
# projectId                                                                             0x72b0d6a6  \
# Donor Count                                                                                   10
# Mean Donation                                                                           6.995419
# Median Donation                                                                         5.847482
# Mode Donation                                  [1.00021748, 1.00118087, 2.0037435, 2.99733228...
# amountUSD_allocation_unmatched                                                         69.954191
# quadratic_amount_allocation_unmatched                                                  28.904906
# amount_boosted_allocation_unmatched                                                    85.064031
# quadratic_amount_boosted_allocation_unmatched                                          34.811307
# amountUSD_allocation_matched                                                          358.081912
# quadratic_amount_allocation_matched                                                   147.958597
# amount_boosted_allocation_matched                                                     435.426245
# quadratic_amount_boosted_allocation_matched                                           178.192316
# SME Percentage Boost                                                                   20.433905
#
# projectId                                                                             0x5351510d  \
# Donor Count                                                                                    8
# Mean Donation                                                                           6.139782
# Median Donation                                                                         5.847482
# Mode Donation                                  [1.00118087, 3.25177668, 3.72995, 5.68897744, ...
# amountUSD_allocation_unmatched                                                         49.118253
# quadratic_amount_allocation_unmatched                                                  14.242025
# amount_boosted_allocation_unmatched                                                    51.418201
# quadratic_amount_boosted_allocation_unmatched                                          14.827779
# amountUSD_allocation_matched                                                           251.42679
# quadratic_amount_allocation_matched                                                    72.902157
# amount_boosted_allocation_matched                                                     263.199778
# quadratic_amount_boosted_allocation_matched                                            75.900519
# SME Percentage Boost                                                                    4.112857
#
# projectId                                                                             0x10b3f00e  \
# Donor Count                                                                                    7
# Mean Donation                                                                           6.210735
# Median Donation                                                                         5.998856
# Mode Donation                                  [1.00118087, 2.86921472, 5.68897744, 5.9988558...
# amountUSD_allocation_unmatched                                                         43.475148
# quadratic_amount_allocation_unmatched                                                   9.528204
# amount_boosted_allocation_unmatched                                                    44.207002
# quadratic_amount_boosted_allocation_unmatched                                           9.540081
# amountUSD_allocation_matched                                                          222.540835
# quadratic_amount_allocation_matched                                                    48.773026
# amount_boosted_allocation_matched                                                     226.287054
# quadratic_amount_boosted_allocation_matched                                            48.833821
# SME Percentage Boost                                                                    0.124649
#
# projectId                                                                             0xc401c980  \
# Donor Count                                                                                    7
# Mean Donation                                                                           5.301241
# Median Donation                                                                         5.688977
# Mode Donation                                  [1.00096975, 1.00118087, 4.09456656, 5.6889774...
# amountUSD_allocation_unmatched                                                         37.108687
# quadratic_amount_allocation_unmatched                                                   7.871441
# amount_boosted_allocation_unmatched                                                    34.562636
# quadratic_amount_boosted_allocation_unmatched                                            7.16612
# amountUSD_allocation_matched                                                          189.952156
# quadratic_amount_allocation_matched                                                    40.292376
# amount_boosted_allocation_matched                                                     176.919416
# quadratic_amount_boosted_allocation_matched                                            36.681977
# SME Percentage Boost                                                                   -8.960499
#
# projectId                                                                             0xcf3165f4
# Donor Count                                                                                    5
# Mean Donation                                                                           2.981766
# Median Donation                                                                         1.843793
# Mode Donation                                  [0.36889034, 1.00118087, 1.84379262, 5.6889774...
# amountUSD_allocation_unmatched                                                         14.908828
# quadratic_amount_allocation_unmatched                                                   1.505835
# amount_boosted_allocation_unmatched                                                    13.487914
# quadratic_amount_boosted_allocation_unmatched                                           1.310392
# amountUSD_allocation_matched                                                           76.315394
# quadratic_amount_allocation_matched                                                     7.708078
# amount_boosted_allocation_matched                                                       69.04201
# quadratic_amount_boosted_allocation_matched                                             6.707644
# SME Percentage Boost                                                                  -12.979033

# %%
tec_qf_sme.dataset
# Out:
#              id   projectId  applicationId       voter grantAddress  \
# 0    0x24a5bbf1  0x64a30a4b             19  0x9ba96198   0xA26d6AEB
# 1    0x3dce13bb  0xc401c980              6  0x9390fa86   0x9390fA86
# 2    0x4cf20243  0x97589cd1              7  0x5136cdfc   0x0035cC37
# 3    0x2b032f10  0xec026845             16  0x524cb61b   0x45b79C6b
# 4    0x0842753b  0xa9bdf738             29  0x524cb61b   0x5041A1C1
# ..          ...         ...            ...         ...          ...
# 248  0x26e1e300  0x97589cd1              7  0x4405f427   0x0035cC37
# 249  0xa21ca1aa  0xec026845             16  0xcdfbbe10   0x45b79C6b
# 250  0x634b5156  0xf1f4942d             24  0xcdfbbe10   0x4f8c531d
# 251  0x4efa29aa  0xcf3165f4             10  0x410d86e3   0x7f3eb18E
# 252  0x7b5b313f  0x64a30a4b             19  0xb5d64294   0xA26d6AEB
#
#            amount  amountUSD  coefficient  rawScore  balance_tec  \
# 0    5.000000e+15   9.184332            2     28.57          0.0
# 1    2.200000e+15   4.094567            1     27.21          0.0
# 2    4.000000e+16  74.446665            1     28.57          0.0
# 3    3.000000e+15   5.583500            1     23.56          0.0
# 4    3.000000e+15   5.583500            1     23.56          0.0
# ..            ...        ...          ...       ...          ...
# 248  1.000000e+15   1.847803            1     29.74          0.0
# 249  1.000000e+15   1.843793            1     21.07          0.0
# 250  1.000000e+15   1.843793            1     21.07          0.0
# 251  1.000000e+15   1.843793            1     18.04          0.0
# 252  3.000000e+15   5.531378            1     18.04          0.0
#
#      tec_tokens_flag  balance_tea  tea_flag  amountUSD_allocation  \
# 0                0.0          3.0       1.0              0.001513
# 1                0.0          0.0       0.0              0.000675
# 2                0.0          0.0       0.0              0.012265
# 3                0.0          0.0       0.0              0.000920
# 4                0.0          0.0       0.0              0.000920
# ..               ...          ...       ...                   ...
# 248              0.0          0.0       0.0              0.000304
# 249              0.0          0.0       0.0              0.000304
# 250              0.0          0.0       0.0              0.000304
# 251              0.0          0.0       0.0              0.000304
# 252              0.0          0.0       0.0              0.000911
#
#      sqrt(amountUSD)  sum(sqrt(amountUSD))  sq(sum(sqrt(amountUSD)))  \
# 0           3.030566             60.250452               3630.117021
# 1           2.023504             15.075191                227.261396
# 2           8.628248             56.397388               3180.665361
# 3           2.362943             47.809680               2285.765459
# 4           2.362943             62.051660               3850.408505
# ..               ...                   ...                       ...
# 248         1.359339             56.397388               3180.665361
# 249         1.357863             47.809680               2285.765459
# 250         1.357863             42.547549               1810.293913
# 251         1.357863              7.801686                 60.866307
# 252         2.351888             60.250452               3630.117021
#
#      quadratic_amount_allocation  quadratic_amount  amount_boosted  \
# 0                       0.002959         17.961853       18.368665
# 1                       0.000185          1.124492        4.094567
# 2                       0.002593         15.737962       74.446665
# 3                       0.001863         11.309989        5.583500
# 4                       0.003139         19.051858        5.583500
# ..                           ...               ...             ...
# 248                     0.002593         15.737962        1.847803
# 249                     0.001863         11.309989        1.843793
# 250                     0.001476          8.957351        1.843793
# 251                     0.000050          0.301167        1.843793
# 252                     0.002959         17.961853        5.531378
#
#      amount_boosted_allocation  sqrt(amount_boosted)  \
# 0                     0.001982              4.285868
# 1                     0.000442              2.023504
# 2                     0.008032              8.628248
# 3                     0.000602              2.362943
# 4                     0.000602              2.362943
# ..                         ...                   ...
# 248                   0.000199              1.359339
# 249                   0.000199              1.357863
# 250                   0.000199              1.357863
# 251                   0.000199              1.357863
# 252                   0.000597              2.351888
#
#      sum(sqrt(amount_boosted))  sq(sum(sqrt(amount_boosted)))  \
# 0                    79.030310                    6245.789911
# 1                    17.371966                     301.785192
# 2                    69.649436                    4851.043974
# 3                    58.552360                    3428.378871
# 4                    77.578445                    6018.415167
# ..                         ...                            ...
# 248                  69.649436                    4851.043974
# 249                  58.552360                    3428.378871
# 250                  47.145265                    2222.675984
# 251                   8.789651                      77.257962
# 252                  79.030310                    6245.789911
#
#      quadratic_amount_boosted_allocation  quadratic_amount_boosted
# 0                               0.003491                 32.355765
# 1                               0.000169                  1.563372
# 2                               0.002711                 25.130407
# 3                               0.001916                 17.760415
# 4                               0.003364                 31.177870
# ..                                   ...                       ...
# 248                             0.002711                 25.130407
# 249                             0.001916                 17.760415
# 250                             0.001242                 11.514377
# 251                             0.000043                  0.400228
# 252                             0.003491                 32.355765
#
# [253 rows x 26 columns]

# %%
tec_qf_sme.dataset[tec_qf_sme.dataset.columns[tec_qf_sme.dataset.columns.str.contains('allocation')]]
# Out:
#      amountUSD_allocation  quadratic_amount_allocation  \
# 0                0.001513                     0.002959
# 1                0.000675                     0.000185
# 2                0.012265                     0.002593
# 3                0.000920                     0.001863
# 4                0.000920                     0.003139
# ..                    ...                          ...
# 248              0.000304                     0.002593
# 249              0.000304                     0.001863
# 250              0.000304                     0.001476
# 251              0.000304                     0.000050
# 252              0.000911                     0.002959
#
#      amount_boosted_allocation  quadratic_amount_boosted_allocation
# 0                     0.001982                             0.003491
# 1                     0.000442                             0.000169
# 2                     0.008032                             0.002711
# 3                     0.000602                             0.001916
# 4                     0.000602                             0.003364
# ..                         ...                                  ...
# 248                   0.000199                             0.002711
# 249                   0.000199                             0.001916
# 250                   0.000199                             0.001242
# 251                   0.000199                             0.000043
# 252                   0.000597                             0.003491
#
# [253 rows x 4 columns]

# %%
list(tec_qf_sme.dataset.columns[tec_qf_sme.dataset.columns.str.contains('allocation')])
# Out:
# ['amountUSD_allocation',
#  'quadratic_amount_allocation',
#  'amount_boosted_allocation',
#  'quadratic_amount_boosted_allocation']

# %%
tec_qf_sme.dataset
