# %%
import pandas as pd

# %%
contributions_df = pd.read_csv('vote_coefficients_input.csv')

# %%
contributions_df
# Out:
#                                                     id  \
# 0    0x24a5bbf100c33c84d6adf041b80650a27e0f8a9739d6...
# 1    0x3dce13bb4ed8831dfe3382d745ed593a70a5830dcc3c...
# 2    0x4cf20243021a45a1a493358b75ef147e264aee102ad0...
# 3    0x2b032f10cb65d0b9efb758931efb30571f83b076e573...
# 4    0x0842753b06ff41ad8507a64154262ca08edd7ad6f551...
# ..                                                 ...
# 252  0x26e1e300155410a03479bcbeaa8a7640aa45bf44c59a...
# 253  0xa21ca1aa9cb0ec2f198152f76e574528a5a5518ca801...
# 254  0x634b51569ff03c125f623d18a51487e7c116cf8df08b...
# 255  0x4efa29aa471f4e1581b9d2fdb972cb4f80157d517aee...
# 256  0x7b5b313f4833bd73cb4358790ed644a6bb2d0c37fe31...
#
#                                              projectId  applicationId  \
# 0    0x64a30a4b92a54a2ad5b7cb48106104d3eb1ca743dd09...             19
# 1    0xc401c980df990c4153febcf89b1b78428be1e1f5020d...              6
# 2    0x97589cd10d5be47bef0513d22cbd9ecb9ce06ec6f9ba...              7
# ...

# %%
outcomes_df = pd.read_csv('tegr1_outcomes.csv')

# %%
outcomes_df
# Out:
#     totalReceived    sumOfSqrt       matched   matchedUSD  \
# 0    4.720000e+20  62249162463  3.400000e+21  3400.869003
# 1    2.710000e+20  50978486818  2.330000e+21  2326.763470
# 2    1.950000e+20  42101615077  1.580000e+21  1576.336421
# 3    2.910000e+20  42317169239  1.500000e+21  1498.591684
# 4    1.030000e+20  33715918017  1.030000e+21  1033.333277
# 5    9.510000e+20  43557208912  9.460000e+20   945.655519
# 6    1.620000e+20  33056938465  9.310000e+20   930.301638
# 7    7.420000e+19  30332871551  8.460000e+20   845.407925
# 8    4.990000e+19  21207449596  4.000000e+20   399.588945
# 9    1.190000e+20  20811181179  3.140000e+20   313.820902
# 10   4.990000e+19  18803626242  3.040000e+20   303.492527
# 11   6.560000e+19  17469843431  2.400000e+20   239.479697
# 12   3.610000e+19  14066272038  1.620000e+20   161.701917
# 13   3.270000e+19  12168620826  1.150000e+20   115.273532
# 14   2.490000e+19   9332806553  6.220000e+19    62.159407
# ...

# %%
outcomes_df['Grant Name'] = outcomes_df['projectName']
outcomes_df['Grant Address'] = outcomes_df['payoutAddress']

# %%
outcomes_df[['Grant Name', 'Grant Address', 'projectId']].to_csv('tegr1_grants.csv', index=False)
