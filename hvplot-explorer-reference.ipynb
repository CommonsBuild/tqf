# %%
import hvplot.pandas

from bokeh.sampledata.penguins import data as df

hvexplorer = hvplot.explorer(df)

# %%
hvexplorer.param.set_param(kind='kde', x='bill_length_mm', y_multi=['bill_depth_mm'], by=['species'])
hvexplorer.labels.title = 'Penguins Scatter'

# %%
hvexplorer
# Out:
# hvDataFrameExplorer(axes=Axes(explorer=..., height=None, legend='right', logx=False, logy=False, name='Axes08081', responsive=False, shared_axes=True, width=None, xlim=None, ylim=None), by=['species'], colormapping=Colormapping(clim=None, cmap='kbc_r', cnorm='linear', color=None, colorbar=None, explorer=..., name='Colormapping08141', rescale_discrete_levels=True, symmetric=False), groupby=[], kind='kde', labels=Labels(clabel='', explorer=..., fontscale=1, name='Labels08188', rot=0, title='Penguins Scatter', xlabel='', ylabel=''), name='hvDataFrameExplorer08048', operations=Operations(aggregator=None, datashade=False, dynspread=False, explorer=..., name='Operations08232', rasterize=False, x_sampling=None, y_sampling=None), style=Style(alpha=1, explorer=..., name='Style08276'), x=None, y='species', y_multi=['bill_depth_mm'], z=None)

# %%
settings = hvexplorer.settings()
settings
# Out:
# {'by': ['species'],
#  'kind': 'scatter',
#  'title': 'Penguins Scatter',
#  'x': 'bill_length_mm',
#  'y': ['bill_depth_mm']}

# %%
df.hvplot(**settings)
# Out:
# :NdOverlay   [species]
#    :Scatter   [bill_length_mm]   (bill_depth_mm)

# %%
hvexplorer.plot_code()
# Out:
# "df.hvplot(by=['species'], kind='scatter', title='Penguins Scatter', x='bill_length_mm', y=['bill_depth_mm'])"

# %%
df.hvplot(by=['species'], kind='scatter', title='Penguins Scatter', x='bill_length_mm', y=['bill_depth_mm'])
# Out:
# :NdOverlay   [species]
#    :Scatter   [bill_length_mm]   (bill_depth_mm)
